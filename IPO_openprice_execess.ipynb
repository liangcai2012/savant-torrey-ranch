# %%
# %matplotlib inline
import socket, yaml, os, cjson, requests, sys, datetime
# root_dir = os.path.dirname(__file__) 
root_dir = os.getcwd()
import pandas as pd
from sqlalchemy import create_engine # database connection
from savant.db.models import IPOInfoUrl, HistoricalIPO, Company, Underwriter, CompanyUnderwriterAssociation
from savant.config import settings
from savant.db.models import Exchange, Sector, Industry

# %%
disk_engine = create_engine(settings.DATABASE_URI)
# companies = pd.read_sql_query('SELECT * FROM company', disk_engine)
from sqlalchemy.engine import reflection
insp = reflection.Inspector.from_engine(disk_engine)
print insp.get_table_names()
# Out:
# INFO:sqlalchemy.engine.base.Engine:SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# INFO:sqlalchemy.engine.base.Engine:()
# INFO:sqlalchemy.engine.base.Engine:SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# INFO:sqlalchemy.engine.base.Engine:()
# INFO:sqlalchemy.engine.base.Engine:SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# INFO:sqlalchemy.engine.base.Engine:()
# DEBUG:sqlalchemy.engine.base.Engine:Col ('name',)
# DEBUG:sqlalchemy.engine.base.Engine:Row (u'company',)
# DEBUG:sqlalchemy.engine.base.Engine:Row (u'company_underwriter_association',)
# DEBUG:sqlalchemy.engine.base.Engine:Row (u'exchange',)
# DEBUG:sqlalchemy.engine.base.Engine:Row (u'historical_ipo',)
# DEBUG:sqlalchemy.engine.base.Engine:Row (u'industry',)
# DEBUG:sqlalchemy.engine.base.Engine:Row (u'ipo_url',)
# DEBUG:sqlalchemy.engine.base.Engine:Row (u'sector',)
# DEBUG:sqlalchemy.engine.base.Engine:Row (u'underwriter',)
# [u'company', u'company_underwriter_association', u'exchange', u'historical_ipo', u'industry', u'ipo_url', u'sector', u'underwriter']

# %%
import socket, yaml, os, cjson, requests, sys, datetime

class ATConnection:
    def __init__(self):
        self.root_url = 'http://127.0.0.1:5000'
    def quoteData(self, params):
        url = self.root_url + '/quoteData'
        return requests.get(url, params=params)
    def quoteStream(self, params): 
        url = self.root_url + '/quoteStream'
        return requests.get(url, params=params)
    def barData(self, params): 
        url = self.root_url + '/barData'
        return requests.get(url, params=params)
    def tickData(self, params): 
        url = self.root_url + '/tickData'
        return requests.get(url, params=params)
    def optionChain(self, params): 
        url = self.root_url + '/optionChain'
        return requests.get(url, params=params)
at = ATConnection()

# %%
companies = Company.query.all()
# Out:
# 2015-07-18 17:13:22,916 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# INFO:sqlalchemy.engine.base.Engine:SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2015-07-18 17:13:22,917 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
# 2015-07-18 17:13:22,918 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# INFO:sqlalchemy.engine.base.Engine:SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2015-07-18 17:13:22,919 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
# 2015-07-18 17:13:22,923 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.base.Engine:BEGIN (implicit)
# 2015-07-18 17:13:22,927 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# 2015-07-18 17:13:22,928 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()

# %%
ipos = HistoricalIPO.query.all()
# Out:
# 2015-07-18 17:29:38,381 INFO sqlalchemy.engine.base.Engine SELECT historical_ipo.company_id AS historical_ipo_company_id, historical_ipo.ipo_date AS historical_ipo_ipo_date, historical_ipo.price AS historical_ipo_price, historical_ipo.shares AS historical_ipo_shares, historical_ipo.outstanding AS historical_ipo_outstanding, historical_ipo.scoop_rating AS historical_ipo_scoop_rating, historical_ipo.first_opening_price AS historical_ipo_first_opening_price, historical_ipo.first_closing_price AS historical_ipo_first_closing_price, historical_ipo.first_trade_time AS historical_ipo_first_trade_time, historical_ipo.first_day_high AS historical_ipo_first_day_high, historical_ipo.first_day_high_percent_change AS historical_ipo_first_day_high_percent_change, historical_ipo.first_day_low AS historical_ipo_first_day_low, historical_ipo.first_day_low_percent_change AS historical_ipo_first_day_low_percent_change, historical_ipo.first_day_volume AS historical_ipo_first_day_volume
# FROM historical_ipo
# INFO:sqlalchemy.engine.base.Engine:SELECT historical_ipo.company_id AS historical_ipo_company_id, historical_ipo.ipo_date AS historical_ipo_ipo_date, historical_ipo.price AS historical_ipo_price, historical_ipo.shares AS historical_ipo_shares, historical_ipo.outstanding AS historical_ipo_outstanding, historical_ipo.scoop_rating AS historical_ipo_scoop_rating, historical_ipo.first_opening_price AS historical_ipo_first_opening_price, historical_ipo.first_closing_price AS historical_ipo_first_closing_price, historical_ipo.first_trade_time AS historical_ipo_first_trade_time, historical_ipo.first_day_high AS historical_ipo_first_day_high, historical_ipo.first_day_high_percent_change AS historical_ipo_first_day_high_percent_change, historical_ipo.first_day_low AS historical_ipo_first_day_low, historical_ipo.first_day_low_percent_change AS historical_ipo_first_day_low_percent_change, historical_ipo.first_day_volume AS historical_ipo_first_day_volume
# FROM historical_ipo
# 2015-07-18 17:29:38,382 INFO sqlalchemy.engine.base.Engine ()
# INFO:sqlalchemy.engine.base.Engine:()
# 2015-07-18 17:29:38,410 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 17:29:38,411 INFO sqlalchemy.engine.base.Engine (3, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(3, 1, 0)

# %%
import pandas.io.data as web
prices = {}

# %%
import sys
if sys.version_info[0] < 3:
    from StringIO import StringIO
else:
    from io import StringIO
names = ['datetime', 'Open', 'High', 'Low', 'Close', 'Volume' ]
parse = lambda x: datetime.datetime.strptime(x, '%Y%m%d%H%M%S%f')

# %%
for ipo in ipos:
    comp =  Company.query.filter_by(id=ipo.company_id).first()
    params = {}
    params['symbol'] = comp.symbol
    params['historyType'] = 1
    params['beginTime'] = ipo.ipo_date.strftime('%Y%m%d%H%M%S') 
    params['endTime'] = (ipo.ipo_date + datetime.timedelta(days=30)).strftime('%Y%m%d%H%M%S')
    connect = at.barData(params=params)    
    try:
        prices[comp.symbol] = pd.read_csv(StringIO(connect.content   ), names=names, parse_dates=[0], date_parser=parse)
    except:
        print comp.symbol
# Out:
# 2015-07-18 18:34:48,103 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:48,105 INFO sqlalchemy.engine.base.Engine (3, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(3, 1, 0)
# 2015-07-18 18:34:48,154 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:48,155 INFO sqlalchemy.engine.base.Engine (5, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(5, 1, 0)
# 2015-07-18 18:34:48,202 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:48,203 INFO sqlalchemy.engine.base.Engine (7, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(7, 1, 0)
# 2015-07-18 18:34:48,254 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:48,255 INFO sqlalchemy.engine.base.Engine (14, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(14, 1, 0)
# 2015-07-18 18:34:48,302 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:48,303 INFO sqlalchemy.engine.base.Engine (17, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(17, 1, 0)
# 2015-07-18 18:34:48,349 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:48,350 INFO sqlalchemy.engine.base.Engine (21, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(21, 1, 0)
# 2015-07-18 18:34:48,399 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:48,400 INFO sqlalchemy.engine.base.Engine (36, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(36, 1, 0)
# 2015-07-18 18:34:48,450 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:48,451 INFO sqlalchemy.engine.base.Engine (44, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(44, 1, 0)
# 2015-07-18 18:34:48,500 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:48,501 INFO sqlalchemy.engine.base.Engine (48, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(48, 1, 0)
# 2015-07-18 18:34:48,550 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:48,551 INFO sqlalchemy.engine.base.Engine (52, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(52, 1, 0)
# 2015-07-18 18:34:48,598 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:48,599 INFO sqlalchemy.engine.base.Engine (53, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(53, 1, 0)
# 2015-07-18 18:34:48,647 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:48,649 INFO sqlalchemy.engine.base.Engine (55, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(55, 1, 0)
# 2015-07-18 18:34:48,698 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:48,699 INFO sqlalchemy.engine.base.Engine (62, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(62, 1, 0)
# 2015-07-18 18:34:48,747 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:48,748 INFO sqlalchemy.engine.base.Engine (66, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(66, 1, 0)
# 2015-07-18 18:34:48,798 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:48,799 INFO sqlalchemy.engine.base.Engine (73, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(73, 1, 0)
# 2015-07-18 18:34:48,849 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:48,850 INFO sqlalchemy.engine.base.Engine (74, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(74, 1, 0)
# 2015-07-18 18:34:48,898 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:48,899 INFO sqlalchemy.engine.base.Engine (79, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(79, 1, 0)
# 2015-07-18 18:34:48,950 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:48,951 INFO sqlalchemy.engine.base.Engine (81, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(81, 1, 0)
# 2015-07-18 18:34:49,003 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:49,004 INFO sqlalchemy.engine.base.Engine (82, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(82, 1, 0)
# 2015-07-18 18:34:49,052 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:49,053 INFO sqlalchemy.engine.base.Engine (93, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(93, 1, 0)
# 2015-07-18 18:34:49,101 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:49,102 INFO sqlalchemy.engine.base.Engine (94, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(94, 1, 0)
# 2015-07-18 18:34:49,149 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:49,150 INFO sqlalchemy.engine.base.Engine (95, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(95, 1, 0)
# 2015-07-18 18:34:49,199 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:49,200 INFO sqlalchemy.engine.base.Engine (98, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(98, 1, 0)
# 2015-07-18 18:34:49,248 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:49,249 INFO sqlalchemy.engine.base.Engine (99, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(99, 1, 0)
# 2015-07-18 18:34:49,297 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:49,297 INFO sqlalchemy.engine.base.Engine (102, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(102, 1, 0)
# 2015-07-18 18:34:49,351 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:49,352 INFO sqlalchemy.engine.base.Engine (110, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(110, 1, 0)
# 2015-07-18 18:34:49,401 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:49,402 INFO sqlalchemy.engine.base.Engine (117, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(117, 1, 0)
# 2015-07-18 18:34:49,451 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:49,453 INFO sqlalchemy.engine.base.Engine (120, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(120, 1, 0)
# 2015-07-18 18:34:49,501 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:49,501 INFO sqlalchemy.engine.base.Engine (124, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(124, 1, 0)
# 2015-07-18 18:34:49,553 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:49,554 INFO sqlalchemy.engine.base.Engine (132, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(132, 1, 0)
# 2015-07-18 18:34:49,603 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:49,604 INFO sqlalchemy.engine.base.Engine (137, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(137, 1, 0)
# 2015-07-18 18:34:49,653 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:49,655 INFO sqlalchemy.engine.base.Engine (145, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(145, 1, 0)
# 2015-07-18 18:34:49,703 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:49,704 INFO sqlalchemy.engine.base.Engine (152, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(152, 1, 0)
# 2015-07-18 18:34:49,752 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:34:49,753 INFO sqlalchemy.engine.base.Engine (157, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(157, 1, 0)
# 2015-07-18 18:34:49,799 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# ...
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:35:40,449 INFO sqlalchemy.engine.base.Engine (5337, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(5337, 1, 0)
# 2015-07-18 18:35:40,497 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:35:40,498 INFO sqlalchemy.engine.base.Engine (5338, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(5338, 1, 0)
# 2015-07-18 18:35:40,549 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:35:40,550 INFO sqlalchemy.engine.base.Engine (5339, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(5339, 1, 0)
# 2015-07-18 18:35:40,598 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:35:40,599 INFO sqlalchemy.engine.base.Engine (5340, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(5340, 1, 0)
# 2015-07-18 18:35:40,647 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:35:40,648 INFO sqlalchemy.engine.base.Engine (5341, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(5341, 1, 0)
# 2015-07-18 18:35:40,698 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:35:40,699 INFO sqlalchemy.engine.base.Engine (5342, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(5342, 1, 0)
# 2015-07-18 18:35:40,756 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:35:40,757 INFO sqlalchemy.engine.base.Engine (5343, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(5343, 1, 0)
# 2015-07-18 18:35:40,808 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:35:40,809 INFO sqlalchemy.engine.base.Engine (5344, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(5344, 1, 0)
# 2015-07-18 18:35:40,857 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:35:40,859 INFO sqlalchemy.engine.base.Engine (5345, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(5345, 1, 0)
# 2015-07-18 18:35:40,906 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:35:40,908 INFO sqlalchemy.engine.base.Engine (5346, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(5346, 1, 0)
# GLMB
# 2015-07-18 18:35:40,955 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:35:40,957 INFO sqlalchemy.engine.base.Engine (5347, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(5347, 1, 0)
# 2015-07-18 18:35:41,007 INFO sqlalchemy.engine.base.Engine SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# INFO:sqlalchemy.engine.base.Engine:SELECT company.id AS company_id, company.name AS company_name, company.symbol AS company_symbol, company.exchange_id AS company_exchange_id, company.sector_id AS company_sector_id, company.industry_id AS company_industry_id, company.market_cap AS company_market_cap, company.float_shares AS company_float_shares, company.prev_close AS company_prev_close, company.prev_volume AS company_prev_volume, company.trailing_pe AS company_trailing_pe, company.nasdaq_beta AS company_nasdaq_beta, company.date_updated AS company_date_updated
# FROM company
# WHERE company.id = ?
#  LIMIT ? OFFSET ?
# 2015-07-18 18:35:41,008 INFO sqlalchemy.engine.base.Engine (5348, 1, 0)
# INFO:sqlalchemy.engine.base.Engine:(5348, 1, 0)
# CRMD

# %%
days = {}

# %%
for sym in prices:
    pcd = prices[sym]
    pcd_higher = pcd [pcd["High"] > pcd.iloc[0]["Open"] * 1.05]
    if pcd_higher.size > 0:
        days[sym] = (pcd.index <= pcd_higher.index[0]).sum() - 1 
    else:
        days[sym] = -1

# %%
result = pd.DataFrame.from_dict (days, orient='index' )
result.columns = pd.Index(['days'])
result["days"].value_counts()
# Out:
#  0     436
# -1     281
#  1      75
#  2      34
#  3      17
#  4      15
#  5      15
#  13     13
#  7      13
#  9      10
#  6      10
#  10      9
#  12      9
#  8       9
#  18      8
#  15      8
#  17      7
#  16      6
#  11      5
#  14      4
#  19      3
#  20      3
#  21      1
# dtype: int64

# %%
result["days"].value_counts() .plot(kind='bar')

# %%
len(prices.keys())
# Out:
# 991

# %%
len(ipos)
# Out:
# 1011

# %%
len(days.keys())
# Out:
# 991
